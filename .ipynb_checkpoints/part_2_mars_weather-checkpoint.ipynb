# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')
# Out:
# The chromedriver version (122.0.6261.94) detected in PATH at C:\Users\Amy\anaconda3\Scripts\chromedriver-win64\chromedriver-win64\chromedriver.exe might not be compatible with the detected chrome version (123.0.6312.58); currently, chromedriver 123.0.6312.58 is recommended for chrome 123.*, so it is advised to delete the driver in PATH and retry

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object

# Gather the html from the browser
html = browser.html

# BeautifulSoup parser
soup = BeautifulSoup(html, 'html.parser')

# Check type of parser object
print(type(soup))
print('-------------')

# Print parser to see html string
print(soup)
# Out:
# <class 'bs4.BeautifulSoup'>
# -------------
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="description"/>
# <title>Mars Temperature Data</title>
# <link href="css/bootstrap.min.5.2.2.css" rel="stylesheet" type="text/css"/>
# <link href="css/temp.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <main>
# <div class="container py-4">
# <header class="pb-3 mb-4 border-bottom">
# <a class="d-flex align-items-center text-dark text-decoration-none" href="/">
# <span class="fs-4">Mission To Mars</span>
# </a>
# </header>
# <div class="p-5 mb-4 bg-light rounded-3">
# <div class="container-fluid py-5">
# <h1 class="display-5 fw-bold">Mars Temperature Data</h1>
# <p class="col-md-8 fs-4">This is Mars data.</p>
# <table class="table">
# <tbody><tr>
# <th>id</th>
# <th>terrestrial_date</th>
# <th>sol</th>
# <th>ls</th>
# <th>month</th>
# <th>min_temp</th>
# <th>pressure</th>
# </tr>
# <tr class="data-row">
# <td>2</td>
# <td>2012-08-16</td>
# <td>10</td>
# <td>155</td>
# <td>6</td>
# <td>-75.0</td>
# <td>739.0</td>
# </tr>
# <tr class="data-row">
# <td>13</td>
# <td>2012-08-17</td>
# <td>11</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>24</td>
# <td>2012-08-18</td>
# <td>12</td>
# <td>156</td>
# <td>6</td>
# <td>-76.0</td>
# <td>741.0</td>
# </tr>
# <tr class="data-row">
# <td>35</td>
# <td>2012-08-19</td>
# <td>13</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>732.0</td>
# </tr>
# <tr class="data-row">
# <td>46</td>
# <td>2012-08-20</td>
# <td>14</td>
# <td>157</td>
# <td>6</td>
# <td>-74.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>57</td>
# <td>2012-08-21</td>
# <td>15</td>
# <td>158</td>
# <td>6</td>
# <td>-78.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td>68</td>
# <td>2012-08-22</td>
# <td>16</td>
# <td>158</td>
# <td>6</td>
# <td>-77.0</td>
# <td>740.0</td>
# </tr>
# <tr class="data-row">
# <td
# <li><strong>Data Disclaimer</strong>: The Centro de Astrobiología includes the following disclaimer for these data:
#                   <blockquote class="blockquote cab-disclaimer">
#                     The information contained in this file is provided by Centro de Astrobiologia (CAB) and is intended for outreach purposes only. Any other use is discouraged. CAB will take no responsibility for any result or publication made base on the content of this file. To access REMS scientific data, visit <a href="http://pds.nasa.gov" rel="nofollow" target="_blank">PDS</a>. The environmental magnitudes given in this file are obtained from the values read by the Rover Environmental Monitoring Station (REMS) on board the Mars Science Laboratory (MSL) rover on Mars. This file provides the environmental magnitudes at REMS location, so MSL rover influences those magnitudes (rover position, rover temperature, rover orientation, rover shade, dust depositions on the rover, etc.) REMS does not take measurements continuously and it takes measurements at different times from one day to another. This fact has influence on the variation of the values given in this file from one day to another . For different reasons (instrument maintenance, instrument calibration, instrument degradation, etc.), some or all of the magnitudes in this file may not be available.
#                   </blockquote>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <footer class="pt-3 mt-4 text-muted border-top">
# <p id="edx">© 2022 This site is operated by edX Boot Camps LLC for educational purposes only.</p>
# </footer>
# </div>
# </main>
# </body></html>

# %%
# This is the code that was attempted for using BeautifulSoup but did not work.

# Extract all rows of data

# # Find the table element
# table = soup.find('table')
# if table:

#     # Find all rows in the table
#     rows = table.find_all('tr')

#     # Store the table in a dictionary
#     mars_weather = {}

#     # Use for-loop to read each row and extract data
#     for row in rows:
#         row_heading = row.find('th')
#         row_data = row.find('td', class_= 'data-row')
    
#         if row_heading and row_data:
#             mars_weather[row_heading.text] = row_data
        
#     # Check if data was extracted (from Xpert Learning Assistant)
#     if mars_weather:
#         print(mars_weather)
#     else:
#         print('No data extracted')
        
# else:
#     print('Table not found')

# # Check that dictionary prints
# print(mars_weather)

# %%
# Extract all table data using Pandas, the Beautiful Soup method did not work (code is still included above, 
# but commented out).

# Read HTML table into a Pandas df. Use [0] to ensure the table is a table, and not a list. Display head to ensure it is
# read correctly.

weather_df = pd.read_html(url)[0]
weather_df.head()
# Out:
#    id terrestrial_date  sol   ls  month  min_temp  pressure
# 0   2       2012-08-16   10  155      6     -75.0     739.0
# 1  13       2012-08-17   11  156      6     -76.0     740.0
# 2  24       2012-08-18   12  156      6     -76.0     741.0
# 3  35       2012-08-19   13  157      6     -74.0     732.0
# 4  46       2012-08-20   14  157      6     -74.0     740.0

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
mars_weather = []

# Loop through the scraped data to create a list of rows
# Use iterrows() method
for index, row in weather_df.iterrows():
    
#     Make a dictionary for the current row. Create keys that coordinate with the df's column names
    row_data = {
        "ID": row['id'],
        "Terrestrial Date (Earth Days)": row['terrestrial_date'],
        "Sol (Martian Days)": row['sol'],
        "Solar Longitude": row['ls'],
        "Martian Month": row['month'],
        "Min Temp Cel": row['min_temp'],
        "Pressure": row['pressure']
    }
    
#     Append to mars_weather dictionary
    mars_weather.append(row_data)
mars_weather
# Out:
# [{'ID': 2,
#   'Terrestrial Date (Earth Days)': '2012-08-16',
#   'Sol (Martian Days)': 10,
#   'Solar Longitude': 155,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 739.0},
#  {'ID': 13,
#   'Terrestrial Date (Earth Days)': '2012-08-17',
#   'Sol (Martian Days)': 11,
#   'Solar Longitude': 156,
#   'Martian Month': 6,
#   'Min Temp Cel': -76.0,
#   'Pressure': 740.0},
#  {'ID': 24,
#   'Terrestrial Date (Earth Days)': '2012-08-18',
#   'Sol (Martian Days)': 12,
#   'Solar Longitude': 156,
#   'Martian Month': 6,
#   'Min Temp Cel': -76.0,
#   'Pressure': 741.0},
#  {'ID': 35,
#   'Terrestrial Date (Earth Days)': '2012-08-19',
#   'Sol (Martian Days)': 13,
#   'Solar Longitude': 157,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 732.0},
#  {'ID': 46,
#   'Terrestrial Date (Earth Days)': '2012-08-20',
#   'Sol (Martian Days)': 14,
#   'Solar Longitude': 157,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 740.0},
#  {'ID': 57,
#   'Terrestrial Date (Earth Days)': '2012-08-21',
#   'Sol (Martian Days)': 15,
#   'Solar Longitude': 158,
#   'Martian Month': 6,
#   'Min Temp Cel': -78.0,
#   'Pressure': 740.0},
#  {'ID': 68,
#   'Terrestrial Date (Earth Days)': '2012-08-22',
#   'Sol (Martian Days)': 16,
#   'Solar Longitude': 158,
#   'Martian Month': 6,
#   'Min Temp Cel': -77.0,
#   'Pressure': 740.0},
#  {'ID': 79,
#   'Terrestrial Date (Earth Days)': '2012-08-23',
#   'Sol (Martian Days)': 17,
#   'Solar Longitude': 159,
#   'Martian Month': 6,
#   'Min Temp Cel': -76.0,
#   'Pressure': 742.0},
#  {'ID': 112,
#   'Terrestrial Date (Earth Days)': '2012-08-27',
#   'Sol (Martian Days)': 21,
#   'Solar Longitude': 161,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 741.0},
#  {'ID': 114,
#   'Terrestrial Date (Earth Days)': '2012-08-28',
#   'Sol (Martian Days)': 22,
#   'Solar Longitude': 162,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 742.0},
#  {'ID': 123,
#   'Terrestrial Date (Earth Days)': '2012-08-29',
#   'Sol (Martian Days)': 23,
#   'Solar Longitude': 162,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 741.0},
#  {'ID': 134,
#   'Terrestrial Date (Earth Days)': '2012-08-30',
#   'Sol (Martian Days)': 24,
#   'Solar Longitude': 163,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 742.0},
#  {'ID': 145,
#   'Terrestrial Date (Earth Days)': '2012-08-31',
#   'Sol (Martian Days)': 25,
#   'Solar Longitude': 163,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 743.0},
#  {'ID': 156,
#   'Terrestrial Date (Earth Days)': '2012-09-01',
#   'Sol (Martian Days)': 26,
#   'Solar Longitude': 164,
#   'Martian Month': 6,
#   'Min Temp Cel': -76.0,
#   'Pressure': 745.0},
#  {'ID': 163,
#   'Terrestrial Date (Earth Days)': '2012-09-02',
#   'Sol (Martian Days)': 27,
#   'Solar Longitude': 164,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 743.0},
#  {'ID': 170,
#   'Terrestrial Date (Earth Days)': '2012-09-03',
#   'Sol (Martian Days)': 28,
#   'Solar Longitude': 165,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 745.0},
#  {'ID': 171,
#   'Terrestrial Date (Earth Days)': '2012-09-04',
#   'Sol (Martian Days)': 29,
#   'Solar Longitude': 166,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 747.0},
#  {'ID': 172,
#   'Terrestrial Date (Earth Days)': '2012-09-05',
#   'Sol (Martian Days)': 30,
#   'Solar Longitude': 166,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 747.0},
#  {'ID': 173,
#   'Terrestrial Date (Earth Days)': '2012-09-06',
#   'Sol (Martian Days)': 31,
#   'Solar Longitude': 167,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 745.0},
#  {'ID': 175,
#   'Terrestrial Date (Earth Days)': '2012-09-08',
#   'Sol (Martian Days)': 33,
#   'Solar Longitude': 168,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 748.0},
#  {'ID': 176,
#   'Terrestrial Date (Earth Days)': '2012-09-10',
#   'Sol (Martian Days)': 34,
#   'Solar Longitude': 168,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 748.0},
#  {'ID': 177,
#   'Terrestrial Date (Earth Days)': '2012-09-11',
#   'Sol (Martian Days)': 35,
#   'Solar Longitude': 169,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 749.0},
#  {'ID': 178,
#   'Terrestrial Date (Earth Days)': '2012-09-12',
#   'Sol (Martian Days)': 36,
#   'Solar Longitude': 169,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 750.0},
#  {'ID': 179,
#   'Terrestrial Date (Earth Days)': '2012-09-13',
#   'Sol (Martian Days)': 37,
#   'Solar Longitude': 170,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 750.0},
#  {'ID': 180,
#   'Terrestrial Date (Earth Days)': '2012-09-14',
#   'Sol (Martian Days)': 38,
#   'Solar Longitude': 171,
#   'Martian Month': 6,
#   'Min Temp Cel': -73.0,
#   'Pressure': 750.0},
#  {'ID': 181,
#   'Terrestrial Date (Earth Days)': '2012-09-15',
#   'Sol (Martian Days)': 39,
#   'Solar Longitude': 171,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 751.0},
#  {'ID': 182,
#   'Terrestrial Date (Earth Days)': '2012-09-16',
#   'Sol (Martian Days)': 40,
#   'Solar Longitude': 172,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 753.0},
#  {'ID': 183,
#   'Terrestrial Date (Earth Days)': '2012-09-17',
#   'Sol (Martian Days)': 41,
#   'Solar Longitude': 172,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 753.0},
#  {'ID': 184,
#   'Terrestrial Date (Earth Days)': '2012-09-18',
#   'Sol (Martian Days)': 42,
#   'Solar Longitude': 173,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 754.0},
#  {'ID': 185,
#   'Terrestrial Date (Earth Days)': '2012-09-19',
#   'Sol (Martian Days)': 43,
#   'Solar Longitude': 173,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 756.0},
#  {'ID': 186,
#   'Terrestrial Date (Earth Days)': '2012-09-20',
#   'Sol (Martian Days)': 44,
#   'Solar Longitude': 174,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 757.0},
#  {'ID': 187,
#   'Terrestrial Date (Earth Days)': '2012-09-21',
#   'Sol (Martian Days)': 45,
#   'Solar Longitude': 175,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 758.0},
#  {'ID': 188,
#   'Terrestrial Date (Earth Days)': '2012-09-22',
#   'Sol (Martian Days)': 46,
#   'Solar Longitude': 175,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 758.0},
#  {'ID': 189,
#   'Terrestrial Date (Earth Days)': '2012-09-23',
#   'Sol (Martian Days)': 47,
#   'Solar Longitude': 176,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 758.0},
#  {'ID': 190,
#   'Terrestrial Date (Earth Days)': '2012-09-24',
#   'Sol (Martian Days)': 48,
#   'Solar Longitude': 176,
#   'Martian Month': 6,
#   'Min Temp Cel': -75.0,
#   'Pressure': 759.0},
#  {'ID': 191,
#   'Terrestrial Date (Earth Days)': '2012-09-25',
#   'Sol (Martian Days)': 49,
#   'Solar Longitude': 177,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 761.0},
#  {'ID': 192,
#   'Terrestrial Date (Earth Days)': '2012-09-26',
#   'Sol (Martian Days)': 50,
#   'Solar Longitude': 177,
#   'Martian Month': 6,
#   'Min Temp Cel': -72.0,
#   'Pressure': 761.0},
#  {'ID': 193,
#   'Terrestrial Date (Earth Days)': '2012-09-27',
#   'Sol (Martian Days)': 51,
#   'Solar Longitude': 178,
#   'Martian Month': 6,
#   'Min Temp Cel': -76.0,
#   'Pressure': 762.0},
#  {'ID': 194,
#   'Terrestrial Date (Earth Days)': '2012-09-28',
#   'Sol (Martian Days)': 52,
#   'Solar Longitude': 179,
#   'Martian Month': 6,
#   'Min Temp Cel': -74.0,
#   'Pressure': 762.0},
#  {'ID': 195,
#   'Terrestrial Date (Earth Days)': '2012-09-29',
#   'Sol (Martian Days)': 53,
#   'Solar Longitude': 179,
#   'Martian Month': 6,
#   'Min Temp Cel': -71.0,
#   'Pressure': 764.0},
#  {'ID': 196,
#   'Terrestrial Date (Earth Days)': '2012-09-30',
#   'Sol (Martian Days)': 54,
#   'Solar Longitude': 180,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 766.0},
#  {'ID': 197,
#   'Terrestrial Date (Earth Days)': '2012-10-01',
#   'Sol (Martian Days)': 55,
#   'Solar Longitude': 180,
#   'Martian Month': 7,
#   'Min Temp Cel': -74.0,
#   'Pressure': 766.0},
#  {'ID': 198,
#   'Terrestrial Date (Earth Days)': '2012-10-02',
#   'Sol (Martian Days)': 56,
#   'Solar Longitude': 181,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 768.0},
#  {'ID': 199,
#   'Terrestrial Date (Earth Days)': '2012-10-03',
#   'Sol (Martian Days)': 57,
#   'Solar Longitude': 181,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 769.0},
#  {'ID': 200,
#   'Terrestrial Date (Earth Days)': '2012-10-04',
#   'Sol (Martian Days)': 58,
#   'Solar Longitude': 182,
#   'Martian Month': 7,
#   'Min Temp Cel': -74.0,
#   'Pressure': 769.0},
#  {'ID': 201,
#   'Terrestrial Date (Earth Days)': '2012-10-05',
#   'Sol (Martian Days)': 59,
#   'Solar Longitude': 183,
#   'Martian Month': 7,
#   'Min Temp Cel': -76.0,
#   'Pressure': 771.0},
#  {'ID': 202,
#   'Terrestrial Date (Earth Days)': '2012-10-06',
#   'Sol (Martian Days)': 60,
#   'Solar Longitude': 183,
#   'Martian Month': 7,
#   'Min Temp Cel': -75.0,
#   'Pressure': 772.0},
#  {'ID': 203,
#   'Terrestrial Date (Earth Days)': '2012-10-07',
#   'Sol (Martian Days)': 61,
#   'Solar Longitude': 184,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 772.0},
#  {'ID': 204,
#   'Terrestrial Date (Earth Days)': '2012-10-08',
#   'Sol (Martian Days)': 62,
#   'Solar Longitude': 184,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 774.0},
#  {'ID': 205,
#   'Terrestrial Date (Earth Days)': '2012-10-09',
#   'Sol (Martian Days)': 63,
#   'Solar Longitude': 185,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 775.0},
#  {'ID': 206,
#   'Terrestrial Date (Earth Days)': '2012-10-10',
#   'Sol (Martian Days)': 64,
#   'Solar Longitude': 186,
#   'Martian Month': 7,
#   'Min Temp Cel': -74.0,
#   'Pressure': 776.0},
#  {'ID': 207,
#   'Terrestrial Date (Earth Days)': '2012-10-11',
#   'Sol (Martian Days)': 65,
#   'Solar Longitude': 186,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 777.0},
#  {'ID': 208,
#   'Terrestrial Date (Earth Days)': '2012-10-12',
#   'Sol (Martian Days)': 66,
#   'Solar Longitude': 187,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 778.0},
#  {'ID': 209,
#   'Terrestrial Date (Earth Days)': '2012-10-13',
#   'Sol (Martian Days)': 67,
#   'Solar Longitude': 187,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 780.0},
#  {'ID': 210,
#   'Terrestrial Date (Earth Days)': '2012-10-14',
#   'Sol (Martian Days)': 68,
#   'Solar Longitude': 188,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 781.0},
#  {'ID': 211,
#   'Terrestrial Date (Earth Days)': '2012-10-15',
#   'Sol (Martian Days)': 69,
#   'Solar Longitude': 189,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 778.0},
#  {'ID': 212,
#   'Terrestrial Date (Earth Days)': '2012-10-17',
#   'Sol (Martian Days)': 70,
#   'Solar Longitude': 189,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 783.0},
#  {'ID': 213,
#   'Terrestrial Date (Earth Days)': '2012-10-18',
#   'Sol (Martian Days)': 71,
#   'Solar Longitude': 190,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 784.0},
#  {'ID': 214,
#   'Terrestrial Date (Earth Days)': '2012-10-19',
#   'Sol (Martian Days)': 72,
#   'Solar Longitude': 190,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 785.0},
#  {'ID': 215,
#   'Terrestrial Date (Earth Days)': '2012-10-20',
#   'Sol (Martian Days)': 73,
#   'Solar Longitude': 191,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 788.0},
#  {'ID': 216,
#   'Terrestrial Date (Earth Days)': '2012-10-21',
#   'Sol (Martian Days)': 74,
#   'Solar Longitude': 192,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 790.0},
#  {'ID': 217,
#   'Terrestrial Date (Earth Days)': '2012-10-22',
#   'Sol (Martian Days)': 75,
#   'Solar Longitude': 192,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 791.0},
#  {'ID': 218,
#   'Terrestrial Date (Earth Days)': '2012-10-23',
#   'Sol (Martian Days)': 76,
#   'Solar Longitude': 193,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 792.0},
#  {'ID': 219,
#   'Terrestrial Date (Earth Days)': '2012-10-24',
#   'Sol (Martian Days)': 77,
#   'Solar Longitude': 193,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 792.0},
#  {'ID': 220,
#   'Terrestrial Date (Earth Days)': '2012-10-25',
#   'Sol (Martian Days)': 78,
#   'Solar Longitude': 194,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 793.0},
#  {'ID': 221,
#   'Terrestrial Date (Earth Days)': '2012-10-26',
#   'Sol (Martian Days)': 79,
#   'Solar Longitude': 195,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 795.0},
#  {'ID': 222,
#   'Terrestrial Date (Earth Days)': '2012-10-27',
#   'Sol (Martian Days)': 80,
#   'Solar Longitude': 195,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 796.0},
#  {'ID': 223,
#   'Terrestrial Date (Earth Days)': '2012-10-28',
#   'Sol (Martian Days)': 81,
#   'Solar Longitude': 196,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 798.0},
#  {'ID': 224,
#   'Terrestrial Date (Earth Days)': '2012-10-29',
#   'Sol (Martian Days)': 82,
#   'Solar Longitude': 196,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 799.0},
#  {'ID': 225,
#   'Terrestrial Date (Earth Days)': '2012-10-30',
#   'Sol (Martian Days)': 83,
#   'Solar Longitude': 197,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 801.0},
#  {'ID': 226,
#   'Terrestrial Date (Earth Days)': '2012-10-31',
#   'Sol (Martian Days)': 84,
#   'Solar Longitude': 198,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 801.0},
#  {'ID': 227,
#   'Terrestrial Date (Earth Days)': '2012-11-01',
#   'Sol (Martian Days)': 85,
#   'Solar Longitude': 198,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 805.0},
#  {'ID': 228,
#   'Terrestrial Date (Earth Days)': '2012-11-02',
#   'Sol (Martian Days)': 86,
#   'Solar Longitude': 199,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 808.0},
#  {'ID': 229,
#   'Terrestrial Date (Earth Days)': '2012-11-03',
#   'Sol (Martian Days)': 87,
#   'Solar Longitude': 199,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 808.0},
#  {'ID': 230,
#   'Terrestrial Date (Earth Days)': '2012-11-04',
#   'Sol (Martian Days)': 88,
#   'Solar Longitude': 200,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 811.0},
#  {'ID': 231,
#   'Terrestrial Date (Earth Days)': '2012-11-05',
#   'Sol (Martian Days)': 89,
#   'Solar Longitude': 201,
#   'Martian Month': 7,
#   'Min Temp Cel': -73.0,
#   'Pressure': 813.0},
#  {'ID': 233,
#   'Terrestrial Date (Earth Days)': '2012-11-06',
#   'Sol (Martian Days)': 90,
#   'Solar Longitude': 201,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 813.0},
#  {'ID': 234,
#   'Terrestrial Date (Earth Days)': '2012-11-07',
#   'Sol (Martian Days)': 91,
#   'Solar Longitude': 202,
#   'Martian Month': 7,
#   'Min Temp Cel': -74.0,
#   'Pressure': 817.0},
#  {'ID': 235,
#   'Terrestrial Date (Earth Days)': '2012-11-08',
#   'Sol (Martian Days)': 92,
#   'Solar Longitude': 202,
#   'Martian Month': 7,
#   'Min Temp Cel': -74.0,
#   'Pressure': 820.0},
#  {'ID': 236,
#   'Terrestrial Date (Earth Days)': '2012-11-09',
#   'Sol (Martian Days)': 93,
#   'Solar Longitude': 203,
#   'Martian Month': 7,
#   'Min Temp Cel': -72.0,
#   'Pressure': 819.0},
#  {'ID': 237,
#   'Terrestrial Date (Earth Days)': '2012-11-10',
#   'Sol (Martian Days)': 94,
#   'Solar Longitude': 204,
#   'Martian Month': 7,
#   'Min Temp Cel': -70.0,
#   'Pressure': 822.0},
#  {'ID': 238,
#   'Terrestrial Date (Earth Days)': '2012-11-11',
#   'Sol (Martian Days)': 95,
#   'Solar Longitude': 204,
#   'Martian Month': 7,
#   'Min Temp Cel': -68.0,
#   'Pressure': 822.0},
#  {'ID': 239,
#   'Terrestrial Date (Earth Days)': '2012-11-12',
#   'Sol (Martian Days)': 96,
#   'Solar Longitude': 205,
#   'Martian Month': 7,
#   'Min Temp Cel': -71.0,
#   'Pressure': 826.0},
#  {'ID': 240,
#   'Terrestrial Date (Earth Days)': '2012-11-13',
#   'Sol (Martian Days)': 97,
#   'Solar Longitude': 206,
#   'Martian Month': 7,
#   'Min Temp Cel': -68.0,
#   'Pressure': 828.0},
#  {'ID': 241,
#   'Terrestrial Date (Earth Days)': '2012-11-14',
#   'Sol (Martian Days)': 98,
#   'Solar Longitude': 206,
#   'Martian Month': 7,
#   'Min Temp Cel': -68.0,
#   'Pressure': 828.0},
#  {'ID': 242,
#   'Terrestrial Date (Earth Days)': '2012-11-15',
#   'Sol (Martian Days)': 99,
#   'Solar Longitude': 207,
#   'Martian Month': 7,
#   'Min Temp Cel': -68.0,
#   'Pressure': 829.0},
#  {'ID': 3,
#   'Terrestrial Date (Earth Days)': '2012-11-16',
#   'Sol (Martian Days)': 100,
#   'Solar Longitude': 207,
#   'Martian Month': 7,
#   'Min Temp Cel': -66.0,
#   'Pressure': 829.0},
#  {'ID': 4,
#   'Terrestrial Date (Earth Days)': '2012-11-17',
#   'Sol (Martian Days)': 101,
#   'Solar Longitude': 208,
#   'Martian Month': 7,
#   'Min Temp Cel': -65.0,
#   'Pressure': 830.0},
#  {'ID': 5,
#   'Terrestrial Date (Earth Days)': '2012-11-18',
#   'Sol (Martian Days)': 102,
#   'Solar Longitude': 209,
#   'Martian Month': 7,
#   'Min Temp Cel': -67.0,
#   'Pressure': 833.0},
#  {'ID': 6,
#   'Terrestrial Date (Earth Days)': '2012-11-19',
#   'Sol (Martian Days)': 103,
#   'Solar Longitude': 209,
#   'Martian Month': 7,
#   'Min Temp Cel': -66.0,
#   'Pressure': 836.0},
#  {'ID': 7,
#   'Terrestrial Date (Earth Days)': '2012-11-20',
#   'Sol (Martian Days)': 104,
#   'Solar Longitude': 210,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 838.0},
#  {'ID': 8,
#   'Terrestrial Date (Earth Days)': '2012-11-21',
#   'Sol (Martian Days)': 105,
#   'Solar Longitude': 211,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 839.0},
#  {'ID': 9,
#   'Terrestrial Date (Earth Days)': '2012-11-23',
#   'Sol (Martian Days)': 106,
#   'Solar Longitude': 211,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 841.0},
#  {'ID': 10,
#   'Terrestrial Date (Earth Days)': '2012-11-24',
#   'Sol (Martian Days)': 107,
#   'Solar Longitude': 212,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 844.0},
#  {'ID': 11,
#   'Terrestrial Date (Earth Days)': '2012-11-25',
#   'Sol (Martian Days)': 108,
#   'Solar Longitude': 212,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 845.0},
#  {'ID': 12,
#   'Terrestrial Date (Earth Days)': '2012-11-26',
#   'Sol (Martian Days)': 109,
#   'Solar Longitude': 213,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 844.0},
#  {'ID': 14,
#   'Terrestrial Date (Earth Days)': '2012-11-27',
#   'Sol (Martian Days)': 110,
#   'Solar Longitude': 214,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 848.0},
#  {'ID': 15,
#   'Terrestrial Date (Earth Days)': '2012-11-28',
#   'Sol (Martian Days)': 111,
#   'Solar Longitude': 214,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 849.0},
#  {'ID': 16,
#   'Terrestrial Date (Earth Days)': '2012-11-29',
#   'Sol (Martian Days)': 112,
#   'Solar Longitude': 215,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 852.0},
#  {'ID': 17,
#   'Terrestrial Date (Earth Days)': '2012-11-30',
#   'Sol (Martian Days)': 113,
#   'Solar Longitude': 216,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 857.0},
#  {'ID': 18,
#   'Terrestrial Date (Earth Days)': '2012-12-01',
#   'Sol (Martian Days)': 114,
#   'Solar Longitude': 216,
#   'Martian Month': 8,
#   'Min Temp Cel': -69.0,
#   'Pressure': 857.0},
#  {'ID': 19,
#   'Terrestrial Date (Earth Days)': '2012-12-02',
#   'Sol (Martian Days)': 115,
#   'Solar Longitude': 217,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 857.0},
#  {'ID': 20,
#   'Terrestrial Date (Earth Days)': '2012-12-03',
#   'Sol (Martian Days)': 116,
#   'Solar Longitude': 217,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 859.0},
#  {'ID': 21,
#   'Terrestrial Date (Earth Days)': '2012-12-04',
#   'Sol (Martian Days)': 117,
#   'Solar Longitude': 218,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 861.0},
#  {'ID': 22,
#   'Terrestrial Date (Earth Days)': '2012-12-05',
#   'Sol (Martian Days)': 118,
#   'Solar Longitude': 219,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 864.0},
#  {'ID': 23,
#   'Terrestrial Date (Earth Days)': '2012-12-06',
#   'Sol (Martian Days)': 119,
#   'Solar Longitude': 219,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 866.0},
#  {'ID': 25,
#   'Terrestrial Date (Earth Days)': '2012-12-07',
#   'Sol (Martian Days)': 120,
#   'Solar Longitude': 220,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 867.0},
#  {'ID': 26,
#   'Terrestrial Date (Earth Days)': '2012-12-08',
#   'Sol (Martian Days)': 121,
#   'Solar Longitude': 221,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 869.0},
#  {'ID': 27,
#   'Terrestrial Date (Earth Days)': '2012-12-09',
#   'Sol (Martian Days)': 122,
#   'Solar Longitude': 221,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 869.0},
#  {'ID': 28,
#   'Terrestrial Date (Earth Days)': '2012-12-10',
#   'Sol (Martian Days)': 123,
#   'Solar Longitude': 222,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 875.0},
#  {'ID': 29,
#   'Terrestrial Date (Earth Days)': '2012-12-11',
#   'Sol (Martian Days)': 124,
#   'Solar Longitude': 223,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 876.0},
#  {'ID': 30,
#   'Terrestrial Date (Earth Days)': '2012-12-12',
#   'Sol (Martian Days)': 125,
#   'Solar Longitude': 223,
#   'Martian Month': 8,
#   'Min Temp Cel': -68.0,
#   'Pressure': 880.0},
#  {'ID': 31,
#   'Terrestrial Date (Earth Days)': '2012-12-13',
#   'Sol (Martian Days)': 126,
#   'Solar Longitude': 224,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 880.0},
#  {'ID': 32,
#   'Terrestrial Date (Earth Days)': '2012-12-14',
#   'Sol (Martian Days)': 127,
#   'Solar Longitude': 224,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 884.0},
#  {'ID': 33,
#   'Terrestrial Date (Earth Days)': '2012-12-15',
#   'Sol (Martian Days)': 128,
#   'Solar Longitude': 225,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 883.0},
#  {'ID': 34,
#   'Terrestrial Date (Earth Days)': '2012-12-16',
#   'Sol (Martian Days)': 129,
#   'Solar Longitude': 226,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 886.0},
#  {'ID': 36,
#   'Terrestrial Date (Earth Days)': '2012-12-17',
#   'Sol (Martian Days)': 130,
#   'Solar Longitude': 226,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 888.0},
#  {'ID': 37,
#   'Terrestrial Date (Earth Days)': '2012-12-18',
#   'Sol (Martian Days)': 131,
#   'Solar Longitude': 227,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 889.0},
#  {'ID': 38,
#   'Terrestrial Date (Earth Days)': '2012-12-19',
#   'Sol (Martian Days)': 132,
#   'Solar Longitude': 228,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 890.0},
#  {'ID': 39,
#   'Terrestrial Date (Earth Days)': '2012-12-20',
#   'Sol (Martian Days)': 133,
#   'Solar Longitude': 228,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 891.0},
#  {'ID': 40,
#   'Terrestrial Date (Earth Days)': '2012-12-21',
#   'Sol (Martian Days)': 134,
#   'Solar Longitude': 229,
#   'Martian Month': 8,
#   'Min Temp Cel': -67.0,
#   'Pressure': 893.0},
#  {'ID': 41,
#   'Terrestrial Date (Earth Days)': '2012-12-22',
#   'Sol (Martian Days)': 135,
#   'Solar Longitude': 230,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 894.0},
#  {'ID': 42,
#   'Terrestrial Date (Earth Days)': '2012-12-23',
#   'Sol (Martian Days)': 136,
#   'Solar Longitude': 230,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 897.0},
#  {'ID': 43,
#   'Terrestrial Date (Earth Days)': '2012-12-24',
#   'Sol (Martian Days)': 137,
#   'Solar Longitude': 231,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 896.0},
#  {'ID': 44,
#   'Terrestrial Date (Earth Days)': '2012-12-25',
#   'Sol (Martian Days)': 138,
#   'Solar Longitude': 232,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 899.0},
#  {'ID': 45,
#   'Terrestrial Date (Earth Days)': '2012-12-26',
#   'Sol (Martian Days)': 139,
#   'Solar Longitude': 232,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 899.0},
#  {'ID': 47,
#   'Terrestrial Date (Earth Days)': '2012-12-27',
#   'Sol (Martian Days)': 140,
#   'Solar Longitude': 233,
#   'Martian Month': 8,
#   'Min Temp Cel': -66.0,
#   'Pressure': 903.0},
#  {'ID': 48,
#   'Terrestrial Date (Earth Days)': '2012-12-28',
#   'Sol (Martian Days)': 141,
#   'Solar Longitude': 233,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 904.0},
#  {'ID': 49,
#   'Terrestrial Date (Earth Days)': '2012-12-29',
#   'Sol (Martian Days)': 142,
#   'Solar Longitude': 234,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 906.0},
#  {'ID': 50,
#   'Terrestrial Date (Earth Days)': '2012-12-31',
#   'Sol (Martian Days)': 143,
#   'Solar Longitude': 235,
#   'Martian Month': 8,
#   'Min Temp Cel': -63.0,
#   'Pressure': 908.0},
#  {'ID': 51,
#   'Terrestrial Date (Earth Days)': '2013-01-01',
#   'Sol (Martian Days)': 144,
#   'Solar Longitude': 235,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 907.0},
#  {'ID': 52,
#   'Terrestrial Date (Earth Days)': '2013-01-02',
#   'Sol (Martian Days)': 145,
#   'Solar Longitude': 236,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 909.0},
#  {'ID': 53,
#   'Terrestrial Date (Earth Days)': '2013-01-03',
#   'Sol (Martian Days)': 146,
#   'Solar Longitude': 237,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 908.0},
#  {'ID': 54,
#   'Terrestrial Date (Earth Days)': '2013-01-04',
#   'Sol (Martian Days)': 147,
#   'Solar Longitude': 237,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 914.0},
#  {'ID': 55,
#   'Terrestrial Date (Earth Days)': '2013-01-05',
#   'Sol (Martian Days)': 148,
#   'Solar Longitude': 238,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 912.0},
#  {'ID': 56,
#   'Terrestrial Date (Earth Days)': '2013-01-06',
#   'Sol (Martian Days)': 149,
#   'Solar Longitude': 239,
#   'Martian Month': 8,
#   'Min Temp Cel': -65.0,
#   'Pressure': 914.0},
#  {'ID': 58,
#   'Terrestrial Date (Earth Days)': '2013-01-07',
#   'Sol (Martian Days)': 150,
#   'Solar Longitude': 239,
#   'Martian Month': 8,
#   'Min Temp Cel': -64.0,
#   'Pressure': 913.0},
#  {'ID': 59,
#   'Terrestrial Date (Earth Days)': '2013-01-08',
#   'Sol (Martian Days)': 151,
#   'Solar Longitude': 240,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 915.0},
#  {'ID': 60,
#   'Terrestrial Date (Earth Days)': '2013-01-09',
#   'Sol (Martian Days)': 152,
#   'Solar Longitude': 241,
#   'Martian Month': 9,
#   'Min Temp Cel': -63.0,
#   'Pressure': 914.0},
#  {'ID': 61,
#   'Terrestrial Date (Earth Days)': '2013-01-10',
#   'Sol (Martian Days)': 153,
#   'Solar Longitude': 241,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 915.0},
#  {'ID': 62,
#   'Terrestrial Date (Earth Days)': '2013-01-11',
#   'Sol (Martian Days)': 154,
#   'Solar Longitude': 242,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 917.0},
#  {'ID': 63,
#   'Terrestrial Date (Earth Days)': '2013-01-12',
#   'Sol (Martian Days)': 155,
#   'Solar Longitude': 243,
#   'Martian Month': 9,
#   'Min Temp Cel': -64.0,
#   'Pressure': 917.0},
#  {'ID': 64,
#   'Terrestrial Date (Earth Days)': '2013-01-13',
#   'Sol (Martian Days)': 156,
#   'Solar Longitude': 243,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 922.0},
#  {'ID': 65,
#   'Terrestrial Date (Earth Days)': '2013-01-14',
#   'Sol (Martian Days)': 157,
#   'Solar Longitude': 244,
#   'Martian Month': 9,
#   'Min Temp Cel': -64.0,
#   'Pressure': 920.0},
#  {'ID': 66,
#   'Terrestrial Date (Earth Days)': '2013-01-15',
#   'Sol (Martian Days)': 158,
#   'Solar Longitude': 245,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 922.0},
#  {'ID': 67,
#   'Terrestrial Date (Earth Days)': '2013-01-16',
#   'Sol (Martian Days)': 159,
#   'Solar Longitude': 245,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 918.0},
#  {'ID': 69,
#   'Terrestrial Date (Earth Days)': '2013-01-17',
#   'Sol (Martian Days)': 160,
#   'Solar Longitude': 246,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 919.0},
#  {'ID': 70,
#   'Terrestrial Date (Earth Days)': '2013-01-18',
#   'Sol (Martian Days)': 161,
#   'Solar Longitude': 246,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 919.0},
#  {'ID': 71,
#   'Terrestrial Date (Earth Days)': '2013-01-19',
#   'Sol (Martian Days)': 162,
#   'Solar Longitude': 247,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 919.0},
#  {'ID': 72,
#   'Terrestrial Date (Earth Days)': '2013-01-20',
#   'Sol (Martian Days)': 163,
#   'Solar Longitude': 248,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 919.0},
#  {'ID': 73,
#   'Terrestrial Date (Earth Days)': '2013-01-21',
#   'Sol (Martian Days)': 164,
#   'Solar Longitude': 248,
#   'Martian Month': 9,
#   'Min Temp Cel': -64.0,
#   'Pressure': 919.0},
#  {'ID': 74,
#   'Terrestrial Date (Earth Days)': '2013-01-22',
#   'Sol (Martian Days)': 165,
#   'Solar Longitude': 249,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 922.0},
#  {'ID': 75,
#   'Terrestrial Date (Earth Days)': '2013-01-23',
#   'Sol (Martian Days)': 166,
#   'Solar Longitude': 250,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 922.0},
#  {'ID': 76,
#   'Terrestrial Date (Earth Days)': '2013-01-24',
#   'Sol (Martian Days)': 167,
#   'Solar Longitude': 250,
#   'Martian Month': 9,
#   'Min Temp Cel': -65.0,
#   'Pressure': 920.0},
#  {'ID': 77,
#   'Terrestrial Date (Earth Days)': '2013-01-25',
#   'Sol (Martian Days)': 168,
#   'Solar Longitude': 251,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 923.0},
#  {'ID': 78,
#   'Terrestrial Date (Earth Days)': '2013-01-26',
#   'Sol (Martian Days)': 169,
#   'Solar Longitude': 252,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 922.0},
#  {'ID': 80,
#   'Terrestrial Date (Earth Days)': '2013-01-27',
#   'Sol (Martian Days)': 170,
#   'Solar Longitude': 252,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 925.0},
#  {'ID': 81,
#   'Terrestrial Date (Earth Days)': '2013-01-28',
#   'Sol (Martian Days)': 171,
#   'Solar Longitude': 253,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 925.0},
#  {'ID': 82,
#   'Terrestrial Date (Earth Days)': '2013-01-29',
#   'Sol (Martian Days)': 172,
#   'Solar Longitude': 254,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 923.0},
#  {'ID': 83,
#   'Terrestrial Date (Earth Days)': '2013-01-30',
#   'Sol (Martian Days)': 173,
#   'Solar Longitude': 254,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 920.0},
#  {'ID': 84,
#   'Terrestrial Date (Earth Days)': '2013-01-31',
#   'Sol (Martian Days)': 174,
#   'Solar Longitude': 255,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 921.0},
#  {'ID': 85,
#   'Terrestrial Date (Earth Days)': '2013-02-01',
#   'Sol (Martian Days)': 175,
#   'Solar Longitude': 256,
#   'Martian Month': 9,
#   'Min Temp Cel': -68.0,
#   'Pressure': 921.0},
#  {'ID': 86,
#   'Terrestrial Date (Earth Days)': '2013-02-02',
#   'Sol (Martian Days)': 176,
#   'Solar Longitude': 256,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 920.0},
#  {'ID': 87,
#   'Terrestrial Date (Earth Days)': '2013-02-03',
#   'Sol (Martian Days)': 177,
#   'Solar Longitude': 257,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 921.0},
#  {'ID': 88,
#   'Terrestrial Date (Earth Days)': '2013-02-04',
#   'Sol (Martian Days)': 178,
#   'Solar Longitude': 258,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 920.0},
#  {'ID': 89,
#   'Terrestrial Date (Earth Days)': '2013-02-06',
#   'Sol (Martian Days)': 179,
#   'Solar Longitude': 258,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 920.0},
#  {'ID': 91,
#   'Terrestrial Date (Earth Days)': '2013-02-07',
#   'Sol (Martian Days)': 180,
#   'Solar Longitude': 259,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 919.0},
#  {'ID': 92,
#   'Terrestrial Date (Earth Days)': '2013-02-08',
#   'Sol (Martian Days)': 181,
#   'Solar Longitude': 260,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 918.0},
#  {'ID': 93,
#   'Terrestrial Date (Earth Days)': '2013-02-09',
#   'Sol (Martian Days)': 182,
#   'Solar Longitude': 260,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 921.0},
#  {'ID': 94,
#   'Terrestrial Date (Earth Days)': '2013-02-10',
#   'Sol (Martian Days)': 183,
#   'Solar Longitude': 261,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 921.0},
#  {'ID': 95,
#   'Terrestrial Date (Earth Days)': '2013-02-11',
#   'Sol (Martian Days)': 184,
#   'Solar Longitude': 261,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 923.0},
#  {'ID': 96,
#   'Terrestrial Date (Earth Days)': '2013-02-12',
#   'Sol (Martian Days)': 185,
#   'Solar Longitude': 262,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 923.0},
#  {'ID': 97,
#   'Terrestrial Date (Earth Days)': '2013-02-13',
#   'Sol (Martian Days)': 186,
#   'Solar Longitude': 263,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 922.0},
#  {'ID': 98,
#   'Terrestrial Date (Earth Days)': '2013-02-14',
#   'Sol (Martian Days)': 187,
#   'Solar Longitude': 263,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 921.0},
#  {'ID': 99,
#   'Terrestrial Date (Earth Days)': '2013-02-15',
#   'Sol (Martian Days)': 188,
#   'Solar Longitude': 264,
#   'Martian Month': 9,
#   'Min Temp Cel': -68.0,
#   'Pressure': 920.0},
#  {'ID': 100,
#   'Terrestrial Date (Earth Days)': '2013-02-16',
#   'Sol (Martian Days)': 189,
#   'Solar Longitude': 265,
#   'Martian Month': 9,
#   'Min Temp Cel': -68.0,
#   'Pressure': 920.0},
#  {'ID': 102,
#   'Terrestrial Date (Earth Days)': '2013-02-17',
#   'Sol (Martian Days)': 190,
#   'Solar Longitude': 265,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 917.0},
#  {'ID': 103,
#   'Terrestrial Date (Earth Days)': '2013-02-18',
#   'Sol (Martian Days)': 191,
#   'Solar Longitude': 266,
#   'Martian Month': 9,
#   'Min Temp Cel': -67.0,
#   'Pressure': 921.0},
#  {'ID': 106,
#   'Terrestrial Date (Earth Days)': '2013-02-23',
#   'Sol (Martian Days)': 196,
#   'Solar Longitude': 269,
#   'Martian Month': 9,
#   'Min Temp Cel': -66.0,
#   'Pressure': 916.0},
#  {'ID': 107,
#   'Terrestrial Date (Earth Days)': '2013-02-24',
#   'Sol (Martian Days)': 197,
#   'Solar Longitude': 270,
#   'Martian Month': 10,
#   'Min Temp Cel': -68.0,
#   'Pressure': 915.0},
#  {'ID': 108,
#   'Terrestrial Date (Earth Days)': '2013-02-25',
#   'Sol (Martian Days)': 198,
#   'Solar Longitude': 271,
#   'Martian Month': 10,
#   'Min Temp Cel': -67.0,
#   'Pressure': 914.0},
#  {'ID': 109,
#   'Terrestrial Date (Earth Days)': '2013-02-26',
#   'Sol (Martian Days)': 199,
#   'Solar Longitude': 271,
#   'Martian Month': 10,
#   'Min Temp Cel': -66.0,
#   'Pressure': 917.0},
#  {'ID': 116,
#   'Terrestrial Date (Earth Days)': '2013-03-23',
#   'Sol (Martian Days)': 223,
#   'Solar Longitude': 287,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 895.0},
#  {'ID': 117,
#   'Terrestrial Date (Earth Days)': '2013-03-24',
#   'Sol (Martian Days)': 224,
#   'Solar Longitude': 287,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 894.0},
#  {'ID': 118,
#   'Terrestrial Date (Earth Days)': '2013-03-25',
#   'Sol (Martian Days)': 225,
#   'Solar Longitude': 288,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 894.0},
#  {'ID': 119,
#   'Terrestrial Date (Earth Days)': '2013-03-26',
#   'Sol (Martian Days)': 226,
#   'Solar Longitude': 288,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 894.0},
#  {'ID': 120,
#   'Terrestrial Date (Earth Days)': '2013-03-27',
#   'Sol (Martian Days)': 227,
#   'Solar Longitude': 289,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 892.0},
#  {'ID': 121,
#   'Terrestrial Date (Earth Days)': '2013-03-28',
#   'Sol (Martian Days)': 228,
#   'Solar Longitude': 290,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 894.0},
#  {'ID': 122,
#   'Terrestrial Date (Earth Days)': '2013-03-29',
#   'Sol (Martian Days)': 229,
#   'Solar Longitude': 290,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 894.0},
#  {'ID': 124,
#   'Terrestrial Date (Earth Days)': '2013-03-30',
#   'Sol (Martian Days)': 230,
#   'Solar Longitude': 291,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 888.0},
#  {'ID': 125,
#   'Terrestrial Date (Earth Days)': '2013-03-31',
#   'Sol (Martian Days)': 231,
#   'Solar Longitude': 292,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 890.0},
#  {'ID': 126,
#   'Terrestrial Date (Earth Days)': '2013-04-01',
#   'Sol (Martian Days)': 232,
#   'Solar Longitude': 292,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 888.0},
#  {'ID': 127,
#   'Terrestrial Date (Earth Days)': '2013-04-02',
#   'Sol (Martian Days)': 233,
#   'Solar Longitude': 293,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 889.0},
#  {'ID': 128,
#   'Terrestrial Date (Earth Days)': '2013-04-03',
#   'Sol (Martian Days)': 234,
#   'Solar Longitude': 293,
#   'Martian Month': 10,
#   'Min Temp Cel': -69.0,
#   'Pressure': 890.0},
#  {'ID': 129,
#   'Terrestrial Date (Earth Days)': '2013-04-04',
#   'Sol (Martian Days)': 235,
#   'Solar Longitude': 294,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 886.0},
#  {'ID': 130,
#   'Terrestrial Date (Earth Days)': '2013-04-05',
#   'Sol (Martian Days)': 236,
#   'Solar Longitude': 295,
#   'Martian Month': 10,
#   'Min Temp Cel': -72.0,
#   'Pressure': 886.0},
#  {'ID': 131,
#   'Terrestrial Date (Earth Days)': '2013-04-06',
#   'Sol (Martian Days)': 237,
#   'Solar Longitude': 295,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 883.0},
#  {'ID': 132,
#   'Terrestrial Date (Earth Days)': '2013-04-07',
#   'Sol (Martian Days)': 238,
#   'Solar Longitude': 296,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 885.0},
#  {'ID': 133,
#   'Terrestrial Date (Earth Days)': '2013-04-08',
#   'Sol (Martian Days)': 239,
#   'Solar Longitude': 297,
#   'Martian Month': 10,
#   'Min Temp Cel': -73.0,
#   'Pressure': 885.0},
#  {'ID': 135,
#   'Terrestrial Date (Earth Days)': '2013-04-09',
#   'Sol (Martian Days)': 240,
#   'Solar Longitude': 297,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 884.0},
#  {'ID': 136,
#   'Terrestrial Date (Earth Days)': '2013-04-10',
#   'Sol (Martian Days)': 241,
#   'Solar Longitude': 298,
#   'Martian Month': 10,
#   'Min Temp Cel': -72.0,
#   'Pressure': 884.0},
#  {'ID': 137,
#   'Terrestrial Date (Earth Days)': '2013-04-11',
#   'Sol (Martian Days)': 242,
#   'Solar Longitude': 298,
#   'Martian Month': 10,
#   'Min Temp Cel': -70.0,
#   'Pressure': 881.0},
#  {'ID': 138,
#   'Terrestrial Date (Earth Days)': '2013-04-12',
#   'Sol (Martian Days)': 243,
#   'Solar Longitude': 299,
#   'Martian Month': 10,
#   'Min Temp Cel': -71.0,
#   'Pressure': 884.0},
#  {'ID': 139,
#   'Terrestrial Date (Earth Days)': '2013-04-13',
#   'Sol (Martian Days)': 244,
#   'Solar Longitude': 300,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 878.0},
#  {'ID': 140,
#   'Terrestrial Date (Earth Days)': '2013-04-14',
#   'Sol (Martian Days)': 245,
#   'Solar Longitude': 300,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 879.0},
#  {'ID': 141,
#   'Terrestrial Date (Earth Days)': '2013-04-15',
#   'Sol (Martian Days)': 246,
#   'Solar Longitude': 301,
#   'Martian Month': 11,
#   'Min Temp Cel': -73.0,
#   'Pressure': 878.0},
#  {'ID': 142,
#   'Terrestrial Date (Earth Days)': '2013-04-16',
#   'Sol (Martian Days)': 247,
#   'Solar Longitude': 301,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 873.0},
#  {'ID': 143,
#   'Terrestrial Date (Earth Days)': '2013-04-17',
#   'Sol (Martian Days)': 248,
#   'Solar Longitude': 302,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 877.0},
#  {'ID': 144,
#   'Terrestrial Date (Earth Days)': '2013-04-18',
#   'Sol (Martian Days)': 249,
#   'Solar Longitude': 303,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 873.0},
#  {'ID': 146,
#   'Terrestrial Date (Earth Days)': '2013-04-19',
#   'Sol (Martian Days)': 250,
#   'Solar Longitude': 303,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 877.0},
#  {'ID': 147,
#   'Terrestrial Date (Earth Days)': '2013-04-20',
#   'Sol (Martian Days)': 251,
#   'Solar Longitude': 304,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 876.0},
#  {'ID': 148,
#   'Terrestrial Date (Earth Days)': '2013-04-22',
#   'Sol (Martian Days)': 252,
#   'Solar Longitude': 304,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 874.0},
#  {'ID': 149,
#   'Terrestrial Date (Earth Days)': '2013-04-23',
#   'Sol (Martian Days)': 253,
#   'Solar Longitude': 305,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 877.0},
#  {'ID': 150,
#   'Terrestrial Date (Earth Days)': '2013-04-24',
#   'Sol (Martian Days)': 254,
#   'Solar Longitude': 306,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 871.0},
#  {'ID': 151,
#   'Terrestrial Date (Earth Days)': '2013-04-25',
#   'Sol (Martian Days)': 255,
#   'Solar Longitude': 306,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 877.0},
#  {'ID': 152,
#   'Terrestrial Date (Earth Days)': '2013-04-26',
#   'Sol (Martian Days)': 256,
#   'Solar Longitude': 307,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 871.0},
#  {'ID': 153,
#   'Terrestrial Date (Earth Days)': '2013-04-27',
#   'Sol (Martian Days)': 257,
#   'Solar Longitude': 308,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 871.0},
#  {'ID': 154,
#   'Terrestrial Date (Earth Days)': '2013-04-28',
#   'Sol (Martian Days)': 258,
#   'Solar Longitude': 308,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 869.0},
#  {'ID': 155,
#   'Terrestrial Date (Earth Days)': '2013-04-29',
#   'Sol (Martian Days)': 259,
#   'Solar Longitude': 309,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 871.0},
#  {'ID': 157,
#   'Terrestrial Date (Earth Days)': '2013-04-30',
#   'Sol (Martian Days)': 260,
#   'Solar Longitude': 309,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 875.0},
#  {'ID': 158,
#   'Terrestrial Date (Earth Days)': '2013-05-01',
#   'Sol (Martian Days)': 261,
#   'Solar Longitude': 310,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 868.0},
#  {'ID': 161,
#   'Terrestrial Date (Earth Days)': '2013-05-08',
#   'Sol (Martian Days)': 268,
#   'Solar Longitude': 314,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 864.0},
#  {'ID': 162,
#   'Terrestrial Date (Earth Days)': '2013-05-09',
#   'Sol (Martian Days)': 269,
#   'Solar Longitude': 315,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 866.0},
#  {'ID': 164,
#   'Terrestrial Date (Earth Days)': '2013-05-10',
#   'Sol (Martian Days)': 270,
#   'Solar Longitude': 315,
#   'Martian Month': 11,
#   'Min Temp Cel': -67.0,
#   'Pressure': 863.0},
#  {'ID': 165,
#   'Terrestrial Date (Earth Days)': '2013-05-11',
#   'Sol (Martian Days)': 271,
#   'Solar Longitude': 316,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 864.0},
#  {'ID': 166,
#   'Terrestrial Date (Earth Days)': '2013-05-12',
#   'Sol (Martian Days)': 272,
#   'Solar Longitude': 316,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 864.0},
#  {'ID': 167,
#   'Terrestrial Date (Earth Days)': '2013-05-13',
#   'Sol (Martian Days)': 273,
#   'Solar Longitude': 317,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 861.0},
#  {'ID': 168,
#   'Terrestrial Date (Earth Days)': '2013-05-14',
#   'Sol (Martian Days)': 274,
#   'Solar Longitude': 318,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 861.0},
#  {'ID': 169,
#   'Terrestrial Date (Earth Days)': '2013-05-15',
#   'Sol (Martian Days)': 275,
#   'Solar Longitude': 318,
#   'Martian Month': 11,
#   'Min Temp Cel': -67.0,
#   'Pressure': 860.0},
#  {'ID': 244,
#   'Terrestrial Date (Earth Days)': '2013-05-16',
#   'Sol (Martian Days)': 276,
#   'Solar Longitude': 319,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 858.0},
#  {'ID': 245,
#   'Terrestrial Date (Earth Days)': '2013-05-17',
#   'Sol (Martian Days)': 277,
#   'Solar Longitude': 319,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 857.0},
#  {'ID': 246,
#   'Terrestrial Date (Earth Days)': '2013-05-18',
#   'Sol (Martian Days)': 278,
#   'Solar Longitude': 320,
#   'Martian Month': 11,
#   'Min Temp Cel': -67.0,
#   'Pressure': 855.0},
#  {'ID': 247,
#   'Terrestrial Date (Earth Days)': '2013-05-19',
#   'Sol (Martian Days)': 279,
#   'Solar Longitude': 321,
#   'Martian Month': 11,
#   'Min Temp Cel': -68.0,
#   'Pressure': 856.0},
#  {'ID': 248,
#   'Terrestrial Date (Earth Days)': '2013-05-20',
#   'Sol (Martian Days)': 280,
#   'Solar Longitude': 321,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 856.0},
#  {'ID': 249,
#   'Terrestrial Date (Earth Days)': '2013-05-21',
#   'Sol (Martian Days)': 281,
#   'Solar Longitude': 322,
#   'Martian Month': 11,
#   'Min Temp Cel': -68.0,
#   'Pressure': 855.0},
#  {'ID': 250,
#   'Terrestrial Date (Earth Days)': '2013-05-22',
#   'Sol (Martian Days)': 282,
#   'Solar Longitude': 322,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 856.0},
#  {'ID': 251,
#   'Terrestrial Date (Earth Days)': '2013-05-23',
#   'Sol (Martian Days)': 283,
#   'Solar Longitude': 323,
#   'Martian Month': 11,
#   'Min Temp Cel': -68.0,
#   'Pressure': 854.0},
#  {'ID': 252,
#   'Terrestrial Date (Earth Days)': '2013-05-24',
#   'Sol (Martian Days)': 284,
#   'Solar Longitude': 323,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 854.0},
#  {'ID': 253,
#   'Terrestrial Date (Earth Days)': '2013-05-25',
#   'Sol (Martian Days)': 285,
#   'Solar Longitude': 324,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 852.0},
#  {'ID': 254,
#   'Terrestrial Date (Earth Days)': '2013-05-26',
#   'Sol (Martian Days)': 286,
#   'Solar Longitude': 325,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 854.0},
#  {'ID': 255,
#   'Terrestrial Date (Earth Days)': '2013-05-27',
#   'Sol (Martian Days)': 287,
#   'Solar Longitude': 325,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 856.0},
#  {'ID': 256,
#   'Terrestrial Date (Earth Days)': '2013-05-29',
#   'Sol (Martian Days)': 288,
#   'Solar Longitude': 326,
#   'Martian Month': 11,
#   'Min Temp Cel': -69.0,
#   'Pressure': 854.0},
#  {'ID': 257,
#   'Terrestrial Date (Earth Days)': '2013-05-30',
#   'Sol (Martian Days)': 289,
#   'Solar Longitude': 326,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 854.0},
#  {'ID': 258,
#   'Terrestrial Date (Earth Days)': '2013-05-31',
#   'Sol (Martian Days)': 290,
#   'Solar Longitude': 327,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 853.0},
#  {'ID': 259,
#   'Terrestrial Date (Earth Days)': '2013-06-01',
#   'Sol (Martian Days)': 291,
#   'Solar Longitude': 327,
#   'Martian Month': 11,
#   'Min Temp Cel': -70.0,
#   'Pressure': 853.0},
#  {'ID': 260,
#   'Terrestrial Date (Earth Days)': '2013-06-02',
#   'Sol (Martian Days)': 292,
#   'Solar Longitude': 328,
#   'Martian Month': 11,
#   'Min Temp Cel': -71.0,
#   'Pressure': 853.0},
#  {'ID': 261,
#   'Terrestrial Date (Earth Days)': '2013-06-03',
#   'Sol (Martian Days)': 293,
#   'Solar Longitude': 329,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 850.0},
#  {'ID': 262,
#   'Terrestrial Date (Earth Days)': '2013-06-04',
#   'Sol (Martian Days)': 294,
#   'Solar Longitude': 329,
#   'Martian Month': 11,
#   'Min Temp Cel': -72.0,
#   'Pressure': 852.0},
#  {'ID': 263,
#   'Terrestrial Date (Earth Days)': '2013-06-05',
#   'Sol (Martian Days)': 295,
#   'Solar Longitude': 330,
#   'Martian Month': 12,
#   'Min Temp Cel': -71.0,
#   'Pressure': 853.0},
#  {'ID': 264,
#   'Terrestrial Date (Earth Days)': '2013-06-06',
#   'Sol (Martian Days)': 296,
#   'Solar Longitude': 330,
#   'Martian Month': 12,
#   'Min Temp Cel': -71.0,
#   'Pressure': 850.0},
#  {'ID': 265,
#   'Terrestrial Date (Earth Days)': '2013-06-07',
#   'Sol (Martian Days)': 297,
#   'Solar Longitude': 331,
#   'Martian Month': 12,
#   'Min Temp Cel': -72.0,
#   'Pressure': 849.0},
#  {'ID': 266,
#   'Terrestrial Date (Earth Days)': '2013-06-08',
#   'Sol (Martian Days)': 298,
#   'Solar Longitude': 331,
#   'Martian Month': 12,
#   'Min Temp Cel': -72.0,
#   'Pressure': 850.0},
#  {'ID': 267,
#   'Terrestrial Date (Earth Days)': '2013-06-09',
#   'Sol (Martian Days)': 299,
#   'Solar Longitude': 332,
#   'Martian Month': 12,
#   'Min Temp Cel': -71.0,
#   'Pressure': 849.0},
#  {'ID': 286,
#   'Terrestrial Date (Earth Days)': '2013-06-10',
#   'Sol (Martian Days)': 300,
#   'Solar Longitude': 333,
#   'Martian Month': 12,
#   'Min Temp Cel': -72.0,
#   'Pressure': 852.0},
#  {'ID': 276,
#   'Terrestrial Date (Earth Days)': '2013-06-11',
#   'Sol (Martian Days)': 301,
#   'Solar Longitude': 333,
#   'Martian Month': 12,
#   'Min Temp Cel': -73.0,
#   'Pressure': 852.0},
#  {'ID': 287,
#   'Terrestrial Date (Earth Days)': '2013-06-12',
#   'Sol (Martian Days)': 302,
#   'Solar Longitude': 334,
#   'Martian Month': 12,
#   'Min Temp Cel': -71.0,
#   'Pressure': 850.0},
#  {'ID': 283,
#   'Terrestrial Date (Earth Days)': '2013-06-13',
#   'Sol (Martian Days)': 303,
#   'Solar Longitude': 334,
#   'Martian Month': 12,
#   'Min Temp Cel': -71.0,
#   'Pressure': 849.0},
#  {'ID': 281,
#   'Terrestrial Date (Earth Days)': '2013-06-14',
#   'Sol (Martian Days)': 304,
#   'Solar Longitude': 335,
#   'Martian Month': 12,
#   'Min Temp Cel': -70.0,
#   'Pressure': 848.0},
#  {'ID': 275,
#   'Terrestrial Date (Earth Days)': '2013-06-15',
#   'Sol (Martian Days)': 305,
#   'Solar Longitude': 335,
# ...
#   'Sol (Martian Days)': 1008,
#   'Solar Longitude': 354,
#   'Martian Month': 12,
#   'Min Temp Cel': -79.0,
#   'Pressure': 844.0},
#  {'ID': 946,
#   'Terrestrial Date (Earth Days)': '2015-06-08',
#   'Sol (Martian Days)': 1009,
#   'Solar Longitude': 354,
#   'Martian Month': 12,
#   'Min Temp Cel': -75.0,
#   'Pressure': 845.0},
#  {'ID': 947,
#   'Terrestrial Date (Earth Days)': '2015-06-09',
#   'Sol (Martian Days)': 1010,
#   'Solar Longitude': 355,
#   'Martian Month': 12,
#   'Min Temp Cel': -74.0,
#   'Pressure': 846.0},
#  {'ID': 948,
#   'Terrestrial Date (Earth Days)': '2015-06-10',
#   'Sol (Martian Days)': 1011,
#   'Solar Longitude': 355,
#   'Martian Month': 12,
#   'Min Temp Cel': -78.0,
#   'Pressure': 845.0},
#  {'ID': 949,
#   'Terrestrial Date (Earth Days)': '2015-06-11',
#   'Sol (Martian Days)': 1012,
#   'Solar Longitude': 356,
#   'Martian Month': 12,
#   'Min Temp Cel': -81.0,
#   'Pressure': 846.0},
#  {'ID': 953,
#   'Terrestrial Date (Earth Days)': '2015-06-12',
#   'Sol (Martian Days)': 1013,
#   'Solar Longitude': 356,
#   'Martian Month': 12,
#   'Min Temp Cel': -80.0,
#   'Pressure': 846.0},
#  {'ID': 950,
#   'Terrestrial Date (Earth Days)': '2015-06-13',
#   'Sol (Martian Days)': 1014,
#   'Solar Longitude': 357,
#   'Martian Month': 12,
#   'Min Temp Cel': -77.0,
#   'Pressure': 846.0},
#  {'ID': 951,
#   'Terrestrial Date (Earth Days)': '2015-06-14',
#   'Sol (Martian Days)': 1015,
#   'Solar Longitude': 357,
#   'Martian Month': 12,
#   'Min Temp Cel': -75.0,
#   'Pressure': 847.0},
#  {'ID': 952,
#   'Terrestrial Date (Earth Days)': '2015-06-16',
#   'Sol (Martian Days)': 1016,
#   'Solar Longitude': 358,
#   'Martian Month': 12,
#   'Min Temp Cel': -76.0,
#   'Pressure': 847.0},
#  {'ID': 955,
#   'Terrestrial Date (Earth Days)': '2015-06-17',
#   'Sol (Martian Days)': 1017,
#   'Solar Longitude': 359,
#   'Martian Month': 12,
#   'Min Temp Cel': -78.0,
#   'Pressure': 850.0},
#  {'ID': 956,
#   'Terrestrial Date (Earth Days)': '2015-06-18',
#   'Sol (Martian Days)': 1018,
#   'Solar Longitude': 359,
#   'Martian Month': 12,
#   'Min Temp Cel': -79.0,
#   'Pressure': 850.0},
#  {'ID': 954,
#   'Terrestrial Date (Earth Days)': '2015-06-19',
#   'Sol (Martian Days)': 1019,
#   'Solar Longitude': 0,
#   'Martian Month': 1,
#   'Min Temp Cel': -81.0,
#   'Pressure': 849.0},
#  {'ID': 938,
#   'Terrestrial Date (Earth Days)': '2015-06-20',
#   'Sol (Martian Days)': 1020,
#   'Solar Longitude': 0,
#   'Martian Month': 1,
#   'Min Temp Cel': -63.0,
#   'Pressure': 832.0},
#  {'ID': 942,
#   'Terrestrial Date (Earth Days)': '2015-06-21',
#   'Sol (Martian Days)': 1021,
#   'Solar Longitude': 1,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 850.0},
#  {'ID': 944,
#   'Terrestrial Date (Earth Days)': '2015-06-22',
#   'Sol (Martian Days)': 1022,
#   'Solar Longitude': 1,
#   'Martian Month': 1,
#   'Min Temp Cel': -75.0,
#   'Pressure': 852.0},
#  {'ID': 943,
#   'Terrestrial Date (Earth Days)': '2015-06-23',
#   'Sol (Martian Days)': 1023,
#   'Solar Longitude': 2,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 851.0},
#  {'ID': 945,
#   'Terrestrial Date (Earth Days)': '2015-06-24',
#   'Sol (Martian Days)': 1024,
#   'Solar Longitude': 2,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 851.0},
#  {'ID': 958,
#   'Terrestrial Date (Earth Days)': '2015-06-25',
#   'Sol (Martian Days)': 1025,
#   'Solar Longitude': 3,
#   'Martian Month': 1,
#   'Min Temp Cel': -74.0,
#   'Pressure': 851.0},
#  {'ID': 957,
#   'Terrestrial Date (Earth Days)': '2015-06-26',
#   'Sol (Martian Days)': 1026,
#   'Solar Longitude': 3,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 851.0},
#  {'ID': 960,
#   'Terrestrial Date (Earth Days)': '2015-06-28',
#   'Sol (Martian Days)': 1028,
#   'Solar Longitude': 4,
#   'Martian Month': 1,
#   'Min Temp Cel': -75.0,
#   'Pressure': 853.0},
#  {'ID': 959,
#   'Terrestrial Date (Earth Days)': '2015-06-29',
#   'Sol (Martian Days)': 1029,
#   'Solar Longitude': 5,
#   'Martian Month': 1,
#   'Min Temp Cel': -75.0,
#   'Pressure': 856.0},
#  {'ID': 961,
#   'Terrestrial Date (Earth Days)': '2015-06-30',
#   'Sol (Martian Days)': 1030,
#   'Solar Longitude': 5,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 855.0},
#  {'ID': 963,
#   'Terrestrial Date (Earth Days)': '2015-07-01',
#   'Sol (Martian Days)': 1031,
#   'Solar Longitude': 6,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 854.0},
#  {'ID': 962,
#   'Terrestrial Date (Earth Days)': '2015-07-02',
#   'Sol (Martian Days)': 1032,
#   'Solar Longitude': 6,
#   'Martian Month': 1,
#   'Min Temp Cel': -74.0,
#   'Pressure': 854.0},
#  {'ID': 965,
#   'Terrestrial Date (Earth Days)': '2015-07-03',
#   'Sol (Martian Days)': 1033,
#   'Solar Longitude': 7,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 856.0},
#  {'ID': 964,
#   'Terrestrial Date (Earth Days)': '2015-07-04',
#   'Sol (Martian Days)': 1034,
#   'Solar Longitude': 7,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 859.0},
#  {'ID': 966,
#   'Terrestrial Date (Earth Days)': '2015-07-05',
#   'Sol (Martian Days)': 1035,
#   'Solar Longitude': 8,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 857.0},
#  {'ID': 967,
#   'Terrestrial Date (Earth Days)': '2015-07-06',
#   'Sol (Martian Days)': 1036,
#   'Solar Longitude': 8,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 856.0},
#  {'ID': 968,
#   'Terrestrial Date (Earth Days)': '2015-07-07',
#   'Sol (Martian Days)': 1037,
#   'Solar Longitude': 9,
#   'Martian Month': 1,
#   'Min Temp Cel': -80.0,
#   'Pressure': 856.0},
#  {'ID': 969,
#   'Terrestrial Date (Earth Days)': '2015-07-08',
#   'Sol (Martian Days)': 1038,
#   'Solar Longitude': 9,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 858.0},
#  {'ID': 970,
#   'Terrestrial Date (Earth Days)': '2015-07-09',
#   'Sol (Martian Days)': 1039,
#   'Solar Longitude': 10,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 857.0},
#  {'ID': 972,
#   'Terrestrial Date (Earth Days)': '2015-07-10',
#   'Sol (Martian Days)': 1040,
#   'Solar Longitude': 10,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 858.0},
#  {'ID': 971,
#   'Terrestrial Date (Earth Days)': '2015-07-11',
#   'Sol (Martian Days)': 1041,
#   'Solar Longitude': 11,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 859.0},
#  {'ID': 973,
#   'Terrestrial Date (Earth Days)': '2015-07-12',
#   'Sol (Martian Days)': 1042,
#   'Solar Longitude': 11,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 859.0},
#  {'ID': 974,
#   'Terrestrial Date (Earth Days)': '2015-07-13',
#   'Sol (Martian Days)': 1043,
#   'Solar Longitude': 12,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 860.0},
#  {'ID': 975,
#   'Terrestrial Date (Earth Days)': '2015-07-14',
#   'Sol (Martian Days)': 1044,
#   'Solar Longitude': 12,
#   'Martian Month': 1,
#   'Min Temp Cel': -79.0,
#   'Pressure': 860.0},
#  {'ID': 978,
#   'Terrestrial Date (Earth Days)': '2015-07-15',
#   'Sol (Martian Days)': 1045,
#   'Solar Longitude': 13,
#   'Martian Month': 1,
#   'Min Temp Cel': -80.0,
#   'Pressure': 861.0},
#  {'ID': 979,
#   'Terrestrial Date (Earth Days)': '2015-07-16',
#   'Sol (Martian Days)': 1046,
#   'Solar Longitude': 13,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 862.0},
#  {'ID': 977,
#   'Terrestrial Date (Earth Days)': '2015-07-17',
#   'Sol (Martian Days)': 1047,
#   'Solar Longitude': 14,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 863.0},
#  {'ID': 976,
#   'Terrestrial Date (Earth Days)': '2015-07-18',
#   'Sol (Martian Days)': 1048,
#   'Solar Longitude': 14,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 864.0},
#  {'ID': 980,
#   'Terrestrial Date (Earth Days)': '2015-07-19',
#   'Sol (Martian Days)': 1049,
#   'Solar Longitude': 15,
#   'Martian Month': 1,
#   'Min Temp Cel': -75.0,
#   'Pressure': 864.0},
#  {'ID': 981,
#   'Terrestrial Date (Earth Days)': '2015-07-20',
#   'Sol (Martian Days)': 1050,
#   'Solar Longitude': 15,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 863.0},
#  {'ID': 983,
#   'Terrestrial Date (Earth Days)': '2015-07-21',
#   'Sol (Martian Days)': 1051,
#   'Solar Longitude': 16,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 864.0},
#  {'ID': 982,
#   'Terrestrial Date (Earth Days)': '2015-07-23',
#   'Sol (Martian Days)': 1052,
#   'Solar Longitude': 16,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 865.0},
#  {'ID': 984,
#   'Terrestrial Date (Earth Days)': '2015-07-24',
#   'Sol (Martian Days)': 1053,
#   'Solar Longitude': 17,
#   'Martian Month': 1,
#   'Min Temp Cel': -79.0,
#   'Pressure': 865.0},
#  {'ID': 985,
#   'Terrestrial Date (Earth Days)': '2015-07-25',
#   'Sol (Martian Days)': 1054,
#   'Solar Longitude': 17,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 867.0},
#  {'ID': 987,
#   'Terrestrial Date (Earth Days)': '2015-07-26',
#   'Sol (Martian Days)': 1055,
#   'Solar Longitude': 17,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 868.0},
#  {'ID': 986,
#   'Terrestrial Date (Earth Days)': '2015-07-27',
#   'Sol (Martian Days)': 1056,
#   'Solar Longitude': 18,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 868.0},
#  {'ID': 988,
#   'Terrestrial Date (Earth Days)': '2015-07-28',
#   'Sol (Martian Days)': 1057,
#   'Solar Longitude': 18,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 867.0},
#  {'ID': 989,
#   'Terrestrial Date (Earth Days)': '2015-07-29',
#   'Sol (Martian Days)': 1058,
#   'Solar Longitude': 19,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 868.0},
#  {'ID': 990,
#   'Terrestrial Date (Earth Days)': '2015-07-30',
#   'Sol (Martian Days)': 1059,
#   'Solar Longitude': 19,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 870.0},
#  {'ID': 992,
#   'Terrestrial Date (Earth Days)': '2015-07-31',
#   'Sol (Martian Days)': 1060,
#   'Solar Longitude': 20,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 870.0},
#  {'ID': 993,
#   'Terrestrial Date (Earth Days)': '2015-08-01',
#   'Sol (Martian Days)': 1061,
#   'Solar Longitude': 20,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 871.0},
#  {'ID': 991,
#   'Terrestrial Date (Earth Days)': '2015-08-02',
#   'Sol (Martian Days)': 1062,
#   'Solar Longitude': 21,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 871.0},
#  {'ID': 994,
#   'Terrestrial Date (Earth Days)': '2015-08-03',
#   'Sol (Martian Days)': 1063,
#   'Solar Longitude': 21,
#   'Martian Month': 1,
#   'Min Temp Cel': -79.0,
#   'Pressure': 871.0},
#  {'ID': 996,
#   'Terrestrial Date (Earth Days)': '2015-08-04',
#   'Sol (Martian Days)': 1064,
#   'Solar Longitude': 22,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 871.0},
#  {'ID': 995,
#   'Terrestrial Date (Earth Days)': '2015-08-05',
#   'Sol (Martian Days)': 1065,
#   'Solar Longitude': 22,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 873.0},
#  {'ID': 997,
#   'Terrestrial Date (Earth Days)': '2015-08-06',
#   'Sol (Martian Days)': 1066,
#   'Solar Longitude': 23,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 875.0},
#  {'ID': 998,
#   'Terrestrial Date (Earth Days)': '2015-08-07',
#   'Sol (Martian Days)': 1067,
#   'Solar Longitude': 23,
#   'Martian Month': 1,
#   'Min Temp Cel': -79.0,
#   'Pressure': 875.0},
#  {'ID': 1000,
#   'Terrestrial Date (Earth Days)': '2015-08-08',
#   'Sol (Martian Days)': 1068,
#   'Solar Longitude': 24,
#   'Martian Month': 1,
#   'Min Temp Cel': -76.0,
#   'Pressure': 874.0},
#  {'ID': 999,
#   'Terrestrial Date (Earth Days)': '2015-08-09',
#   'Sol (Martian Days)': 1069,
#   'Solar Longitude': 24,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 876.0},
#  {'ID': 1001,
#   'Terrestrial Date (Earth Days)': '2015-08-10',
#   'Sol (Martian Days)': 1070,
#   'Solar Longitude': 25,
#   'Martian Month': 1,
#   'Min Temp Cel': -80.0,
#   'Pressure': 877.0},
#  {'ID': 1002,
#   'Terrestrial Date (Earth Days)': '2015-08-11',
#   'Sol (Martian Days)': 1071,
#   'Solar Longitude': 25,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 878.0},
#  {'ID': 1003,
#   'Terrestrial Date (Earth Days)': '2015-08-12',
#   'Sol (Martian Days)': 1072,
#   'Solar Longitude': 26,
#   'Martian Month': 1,
#   'Min Temp Cel': -78.0,
#   'Pressure': 879.0},
#  {'ID': 1004,
#   'Terrestrial Date (Earth Days)': '2015-08-13',
#   'Sol (Martian Days)': 1073,
#   'Solar Longitude': 26,
#   'Martian Month': 1,
#   'Min Temp Cel': -82.0,
#   'Pressure': 879.0},
#  {'ID': 1005,
#   'Terrestrial Date (Earth Days)': '2015-08-14',
#   'Sol (Martian Days)': 1074,
#   'Solar Longitude': 27,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 878.0},
#  {'ID': 1006,
#   'Terrestrial Date (Earth Days)': '2015-08-15',
#   'Sol (Martian Days)': 1075,
#   'Solar Longitude': 27,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 879.0},
#  {'ID': 1007,
#   'Terrestrial Date (Earth Days)': '2015-08-16',
#   'Sol (Martian Days)': 1076,
#   'Solar Longitude': 28,
#   'Martian Month': 1,
#   'Min Temp Cel': -81.0,
#   'Pressure': 880.0},
#  {'ID': 1008,
#   'Terrestrial Date (Earth Days)': '2015-08-17',
#   'Sol (Martian Days)': 1077,
#   'Solar Longitude': 28,
#   'Martian Month': 1,
#   'Min Temp Cel': -79.0,
#   'Pressure': 880.0},
#  {'ID': 1009,
#   'Terrestrial Date (Earth Days)': '2015-08-18',
#   'Sol (Martian Days)': 1078,
#   'Solar Longitude': 29,
#   'Martian Month': 1,
#   'Min Temp Cel': -80.0,
#   'Pressure': 881.0},
#  {'ID': 1010,
#   'Terrestrial Date (Earth Days)': '2015-08-19',
#   'Sol (Martian Days)': 1079,
#   'Solar Longitude': 29,
#   'Martian Month': 1,
#   'Min Temp Cel': -80.0,
#   'Pressure': 882.0},
#  {'ID': 1013,
#   'Terrestrial Date (Earth Days)': '2015-08-20',
#   'Sol (Martian Days)': 1080,
#   'Solar Longitude': 29,
#   'Martian Month': 1,
#   'Min Temp Cel': -77.0,
#   'Pressure': 882.0},
#  {'ID': 1011,
#   'Terrestrial Date (Earth Days)': '2015-08-21',
#   'Sol (Martian Days)': 1081,
#   'Solar Longitude': 30,
#   'Martian Month': 2,
#   'Min Temp Cel': -77.0,
#   'Pressure': 882.0},
#  {'ID': 1012,
#   'Terrestrial Date (Earth Days)': '2015-08-22',
#   'Sol (Martian Days)': 1082,
#   'Solar Longitude': 30,
#   'Martian Month': 2,
#   'Min Temp Cel': -79.0,
#   'Pressure': 882.0},
#  {'ID': 1014,
#   'Terrestrial Date (Earth Days)': '2015-08-23',
#   'Sol (Martian Days)': 1083,
#   'Solar Longitude': 31,
#   'Martian Month': 2,
#   'Min Temp Cel': -80.0,
#   'Pressure': 883.0},
#  {'ID': 1015,
#   'Terrestrial Date (Earth Days)': '2015-08-24',
#   'Sol (Martian Days)': 1084,
#   'Solar Longitude': 31,
#   'Martian Month': 2,
#   'Min Temp Cel': -78.0,
#   'Pressure': 885.0},
#  {'ID': 1017,
#   'Terrestrial Date (Earth Days)': '2015-08-25',
#   'Sol (Martian Days)': 1085,
#   'Solar Longitude': 32,
#   'Martian Month': 2,
#   'Min Temp Cel': -79.0,
#   'Pressure': 886.0},
#  {'ID': 1016,
#   'Terrestrial Date (Earth Days)': '2015-08-26',
#   'Sol (Martian Days)': 1086,
#   'Solar Longitude': 32,
#   'Martian Month': 2,
#   'Min Temp Cel': -77.0,
#   'Pressure': 885.0},
#  {'ID': 1019,
#   'Terrestrial Date (Earth Days)': '2015-08-27',
#   'Sol (Martian Days)': 1087,
#   'Solar Longitude': 33,
#   'Martian Month': 2,
#   'Min Temp Cel': -78.0,
#   'Pressure': 885.0},
#  {'ID': 1020,
#   'Terrestrial Date (Earth Days)': '2015-08-29',
#   'Sol (Martian Days)': 1088,
#   'Solar Longitude': 33,
#   'Martian Month': 2,
#   'Min Temp Cel': -77.0,
#   'Pressure': 885.0},
#  {'ID': 1018,
#   'Terrestrial Date (Earth Days)': '2015-08-30',
#   'Sol (Martian Days)': 1089,
#   'Solar Longitude': 34,
#   'Martian Month': 2,
#   'Min Temp Cel': -76.0,
#   'Pressure': 885.0},
#  {'ID': 1021,
#   'Terrestrial Date (Earth Days)': '2015-08-31',
#   'Sol (Martian Days)': 1090,
#   'Solar Longitude': 34,
#   'Martian Month': 2,
#   'Min Temp Cel': -78.0,
#   'Pressure': 886.0},
#  {'ID': 1022,
#   'Terrestrial Date (Earth Days)': '2015-09-01',
#   'Sol (Martian Days)': 1091,
#   'Solar Longitude': 35,
#   'Martian Month': 2,
#   'Min Temp Cel': -77.0,
#   'Pressure': 886.0},
#  {'ID': 1023,
#   'Terrestrial Date (Earth Days)': '2015-09-02',
#   'Sol (Martian Days)': 1092,
#   'Solar Longitude': 35,
#   'Martian Month': 2,
#   'Min Temp Cel': -79.0,
#   'Pressure': 886.0},
#  {'ID': 1024,
#   'Terrestrial Date (Earth Days)': '2015-09-03',
#   'Sol (Martian Days)': 1093,
#   'Solar Longitude': 36,
#   'Martian Month': 2,
#   'Min Temp Cel': -77.0,
#   'Pressure': 887.0},
#  {'ID': 1026,
#   'Terrestrial Date (Earth Days)': '2015-09-04',
#   'Sol (Martian Days)': 1094,
#   'Solar Longitude': 36,
#   'Martian Month': 2,
#   'Min Temp Cel': -80.0,
#   'Pressure': 888.0},
#  ...]

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names

# Create the list of columns using the keys from the previous cell
columns = ['ID', 'Terrestrial Date (Earth Days)', 'Sol (Martian Days)', 'Solar Longitude', 'Martian Month', 'Min Temp Cel', 
           'Pressure']

# Use the list of rows from the previous cell, aka mars_weather
# Create the Pandas df
mars_weather_df = pd.DataFrame(mars_weather, columns = columns)

# %%
# Confirm DataFrame was created successfully
# Display the df head()
mars_weather_df
# Out:
#         ID Terrestrial Date (Earth Days)  Sol (Martian Days)  Solar Longitude  \
# 0        2                    2012-08-16                  10              155
# 1       13                    2012-08-17                  11              156
# 2       24                    2012-08-18                  12              156
# 3       35                    2012-08-19                  13              157
# 4       46                    2012-08-20                  14              157
# ...    ...                           ...                 ...              ...
# 1862  1889                    2018-02-23                1973              133
# 1863  1892                    2018-02-24                1974              134
# 1864  1894                    2018-02-25                1975              134
# 1865  1893                    2018-02-26                1976              135
# 1866  1895                    2018-02-27                1977              135
#
#       Martian Month  Min Temp Cel  Pressure
# 0                 6         -75.0     739.0
# 1                 6         -76.0     740.0
# 2                 6         -76.0     741.0
# 3                 6         -74.0     732.0
# 4                 6         -74.0     740.0
# ...             ...           ...       ...
# 1862              5         -78.0     730.0
# 1863              5         -77.0     729.0
# 1864              5         -76.0     729.0
# 1865              5         -77.0     728.0
# 1866              5         -77.0     727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mars_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             1867 non-null   int64
#  1   Terrestrial Date (Earth Days)  1867 non-null   object
#  2   Sol (Martian Days)             1867 non-null   int64
#  3   Solar Longitude                1867 non-null   int64
#  4   Martian Month                  1867 non-null   int64
#  5   Min Temp Cel                   1867 non-null   float64
#  6   Pressure                       1867 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 102.2+ KB

# %%
# Change data types for data analysis

# Change Terrestrial Date to datetime data type
mars_weather_df['Terrestrial Date (Earth Days)'] = pd.to_datetime(mars_weather_df['Terrestrial Date (Earth Days)'], 
                                                                  dayfirst=False)

mars_weather_df
# Out:
#         ID Terrestrial Date (Earth Days)  Sol (Martian Days)  Solar Longitude  \
# 0        2                    2012-08-16                  10              155
# 1       13                    2012-08-17                  11              156
# 2       24                    2012-08-18                  12              156
# 3       35                    2012-08-19                  13              157
# 4       46                    2012-08-20                  14              157
# ...    ...                           ...                 ...              ...
# 1862  1889                    2018-02-23                1973              133
# 1863  1892                    2018-02-24                1974              134
# 1864  1894                    2018-02-25                1975              134
# 1865  1893                    2018-02-26                1976              135
# 1866  1895                    2018-02-27                1977              135
#
#       Martian Month  Min Temp Cel  Pressure
# 0                 6         -75.0     739.0
# 1                 6         -76.0     740.0
# 2                 6         -76.0     741.0
# 3                 6         -74.0     732.0
# 4                 6         -74.0     740.0
# ...             ...           ...       ...
# 1862              5         -78.0     730.0
# 1863              5         -77.0     729.0
# 1864              5         -76.0     729.0
# 1865              5         -77.0     728.0
# 1866              5         -77.0     727.0
#
# [1867 rows x 7 columns]

# %%
# Confirm type changes were successful by examining data types again
mars_weather_df.info()
print('-------------------------------')
mars_weather_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             1867 non-null   int64
#  1   Terrestrial Date (Earth Days)  1867 non-null   datetime64[ns]
#  2   Sol (Martian Days)             1867 non-null   int64
#  3   Solar Longitude                1867 non-null   int64
#  4   Martian Month                  1867 non-null   int64
#  5   Min Temp Cel                   1867 non-null   float64
#  6   Pressure                       1867 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 102.2 KB
# -------------------------------
#    ID Terrestrial Date (Earth Days)  Sol (Martian Days)  Solar Longitude  \
# 0   2                    2012-08-16                  10              155
# 1  13                    2012-08-17                  11              156
# 2  24                    2012-08-18                  12              156
# 3  35                    2012-08-19                  13              157
# 4  46                    2012-08-20                  14              157
#
#    Martian Month  Min Temp Cel  Pressure
# 0              6         -75.0     739.0
# 1              6         -76.0     740.0
# 2              6         -76.0     741.0
# 3              6         -74.0     732.0
# 4              6         -74.0     740.0

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?

print(f'There are {mars_weather_df["Martian Month"].nunique()} months on Mars.')
# Out:
# There are 12 months on Mars.

# %%
# 2. How many Martian days' worth of data are there?

print(f'There are {mars_weather_df["Sol (Martian Days)"].nunique()} Martian days worth of data in this data set.')
# Out:
# There are 1867 Martian days worth of data in this data set.

# %%
# 3. What is the average low temperature by month?

# Use .groupby() to group the average low temp by month
avg_temp = mars_weather_df.groupby("Martian Month")["Min Temp Cel"].mean()

print(avg_temp)
# Out:
# Martian Month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: Min Temp Cel, dtype: float64

# %%
# Plot the average temperature by month

# Create simple df with avg temp by Martian month
avg_temp_df = avg_temp.reset_index()
avg_temp_df.rename(columns={'Min Temp Cel':'Min Temp Avg'}, inplace=True)

# Plot using a bar chart
avg_temp_df.plot(x='Martian Month', y='Min Temp Avg', kind='bar', color='blue')

# Add labels and title
plt.xlabel('Martian Month')
plt.ylabel('Min Avg Temp Celsius')
plt.title('Minimum Average Temperature (C) by Martian Month')

# Save the plot
plt.savefig('Mars_Weather_Results/min_avg_temp_by_month.png')

# Show the plot
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location

# Group by 'Martian Month' and find the minimum and maximum 'Min Temp Avg'
coldest_month = avg_temp_df.groupby('Martian Month')['Min Temp Avg'].min()
hottest_month = avg_temp_df.groupby('Martian Month')['Min Temp Avg'].max()

# Find the coldest and hottest months using .idxmin() and .idxmax()
# .idxmin() and .idxmax() find the min and max temperature and returns the corresponding month for each
# From Xpert Learning Assistant
coldest = coldest_month.idxmin()
hottest = hottest_month.idxmax()

print("Coldest Month:", coldest)
print("Hottest Month:", hottest)
# Out:
# Coldest Month: 3
# Hottest Month: 8

# %%
# 4. Average pressure by Martian month

# Use .groupby to help get the avg pressure by month
avg_pressure = mars_weather_df.groupby('Martian Month')['Pressure'].mean()

print(avg_pressure)
# Out:
# Martian Month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: Pressure, dtype: float64

# %%
# Plot the average pressure by month

# Create simple df with avg temp by Martian month
avg_pressure_df =  avg_pressure.reset_index()
avg_pressure_df.rename(columns={'Pressure':'Avg Pressure'}, inplace=True)

# Plot using a bar chart
avg_pressure_df.plot(x='Martian Month', y='Avg Pressure', kind='bar', color='green')

# Add labels and title
plt.xlabel('Martian Month')
plt.ylabel('Avg Pressure')
plt.title('Average Pressure by Martian Month')

# Save the plot
plt.savefig('Mars_Weather_Results/avg_pressure_by_month.png')

# Show the plot
plt.show()

# %%
# Use .groupby() to 
# sol_per_mmonth = mars_weather_df.groupby("Martian Month")["Sol (Martian Days)"].nunique()
# sol_per_mmonth

# Try mars_weather_df.groupby("Solar Longitude")["Martian Month"].value_counts() to see how many times
# month_counts = mars_weather_df.groupby("Solar Longitude")["Martian Month"].value_counts()
# month_counts

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

# Using Xpert Learning Assistant
# Create variable for Earth day minutes and Sol minutes (earth day: 24(hours)*60 = 1440 minutes;
#     sol = 24 hours and 39 min = 24.65 hours * 60 = 1479 minutes)


# Calculate sol in a martian year


# Convert sol to earth days

# Calculate Martian year in earth days

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
mars_weather_df.to_csv('Mars_Weather_Results/mars_weather_data.csv', index=False)

# %%
browser.quit()
